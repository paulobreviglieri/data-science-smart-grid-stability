# %% [markdown]
# # Predicting Smart Grid Stability with Deep Learning
# ### Release 1.0 - August, 2020
# ### Paulo Breviglieri, Türkücan Erdem, Süleyman Eken

# %% [markdown]
# ## Foreword

# %% [markdown]
# <p style="text-align: justify">This notebook is based on the "<b>Electrical Grid Stability Simulated Dataset</b>", created by Vadim Arzamasov (Karlsruher Institut für Technologie, Karlsruhe, Germany) and donated to the <b>University of California (UCI) Machine Learning Repository</b> (link <a href="https://archive.ics.uci.edu/ml/datasets/Electrical+Grid+Stability+Simulated+Data+#">here</a>), where it is currently hosted.</p>
# <p style="text-align: justify">Two primary references support this machine learning exercise and demand special mention:</p>
# <ol>
#     <li>"<em><b>Taming instabilities in power grid networks by decentralized control</b></em>" (B. Schäfer, et al, The European Physical Journal, Special Topics, 2016, 225.3: 569-582), in which Dr. Schäfer (Network Dynamics, Max Planck Institute for Dynamics and Self-Organization - MPIDS, Göttingen, Germany) and his co-authors describe in detail the DSGC (Decentral Smart Grid Control) differential equation-based model to assess stability of smart grids;</li>
#     <p></p>
#     <li>"<em><b>Towards Concise Models of Grid Stability</b></em>" (V. Arzamasov, K. Böhm and P. Jochem, 2018 IEEE International Conference on Communications, Control, and Computing Technologies for Smart Grids (SmartGridComm), Aalborg, 2018, pp. 1-6), in which Dr. Arzamasov and his co-authors explore how data-mining techniques can address DSGC model simplifications.</li>
# </ol>
# <p style="text-align: justify">The author is particularly thankful for Dr. Arzamasov's personal guidance and comments on the overall dataset structure.</p>
# <p style="text-align: justify">Logic enhancement and code forking are welcome and encouraged provided that this work is properly referenced. Thank you.</p>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1. Renewable Energy Sources and Smart Grids

# %% [markdown]
# <p style="text-align: justify">The ascent of renewable energy sources provides the global community with a much demanded alternative to traditional, finite and climate-unfriendly fossil fuels. However, their adoption poses a set of new paradigms, out of which two interrelated aspects deserve particular attention:</p>
# <ul>
#     <li style="text-align: justify">Prior to the rise of renewable energy sources, the traditional operating ecosystem involved few production entities (sources) supplying energy to consumers over unidirectional flows. With the advent of renewable options, end users (households and enterprises) now not only consume energy but have the ability to produce and supply it - hence a new term to designate them, '<b>prosumers</b>'. As a result, energy flow within distribution grids - '<b>smart grids</b>' - has become <b>bidirectional</b>;</li>
#     <li style="text-align: justify">Despite the increased flexibility brought in by the introduction of renewable sources and the aforementioned emergence of 'prosumers', the management of supply and demand in a more complex generation / distribution / consumption environment and the related economic implications (particularly the decision to buy energy at a given price or not) have become even more challenging.</li>
# </ul>
# <p style="text-align: justify">Relevant contributions on how to tackle the requirements of such new scenario have been offered by academy and industry over the past years. Special attention has been devoted to the study of <b>smart grid stability</b>.</p>

# %% [markdown]
# ### 1.2. Modeling grid stability

# %% [markdown]
# <p style="text-align: justify">In a smart grid, consumer demand information is collected, centrally evaluated against current supply conditions and the resulting proposed price information is sent back to customers for them to decide about usage. As the whole process is time-dependent, dinamically estimating <b>grid stability</b> becomes not only a concern but a major requirement.</p>
# <p style="text-align: justify">Put simply, the objective is to understand and plan for both energy production and/or consumption disturbances and fluctuations introduced by system participants in a dynamic way, taking into consideration not only technical aspects but also how participants respond to changes in the associated economic aspects (energy price).</p>
# <p style="text-align: justify">The work of researchers cited in foreword focuses on <b>Decentral Smart Grid Control</b> (DSGC) systems, a methodology strictly tied to monitoring one particular property of the grid - its frequency.</p>
# <p style="text-align: justify">The term '<em>frequency</em>' refers to the alternate current (AC) frequency, measured in cycles per second or its equivalent unit, Hertz (Hz). Around the world AC frequencies of either 50 or 60 Hz are utilized in electric power generation-distribution systems.</p>
# <p style="text-align: justify">It is known that the electrical signal frequency "<em>increases in times of excess generation, while it decreases in times of underproduction</em>" [1]. Therefore, <b>measuring the grid frequency</b> at the premise of each customer would suffice to provide the network administrator with all required information about the current <b>network power balance</b>, so that it can price its energy offering - and inform consumers - accordingly.</p>
# <p style="text-align: justify">The DSGC differential equation-based mathematical model described in [1] and assessed in [2] aims at identifying grid instability for a reference <b>4-node star</b> architecture, comprising one power source (a centralized generation node) supplying energy to three consumption nodes. The model takes into consideration inputs (features) related to:
#     <ul>
#         <li>the total <b>power balance</b> (nominal power produced or consumed at each grid node);</li>
#         <li>the response time of participants to adjust consumption and/or production in response to price changes (referred to as "<b>reaction time</b>);</li>
#         <li>energy <b>price elasticity</b>.</li>
#     </ul>

# %% [markdown]
# <img src="https://i.imgur.com/hvmW0cg.png" width="500" height="100">

# %% [markdown]
# ### 1.3. Addressing simplifications in the model

# %% [markdown]
# <p style="text-align: justify">So we have a mathematical model with which grid instability can be predicted! The need of a tool to predict grid instability would have been met, and the binary classification ("stable" versus "unstable") problem would be solved! However, the execution of this model relies on significant <b>simplifications</b>.</p>
# <p style="text-align: justify">A differential equation-based model can be manipulated in several ways. One traditional approach consists in running simulations with a combination of fixed values for one subset of variables and fixed value distributions for the remaining subset. As elegantly depicted in [2], this strategy leads to <b>two primary issues</b>, referred to as the "fixed inputs issue" and the "equality issue". Please refer to [2] for a comprehensive assessment of both issues.</p>
# <p style="text-align: justify">Alternative approaches have been proposed to overcome the inherent DSGC model simplifications. In particular, Dr. Arzamasov's team at the KIT suggest the use of machine learning - <b>decision trees (CART)</b> - and space-filling designs to process results from simulations with different DSGC parameter configurations.</p>
# <p>In other words, machine learning is used in [2] in the following way:</p>
# <ol>
#     <li>A given set of input parameters (call it a 'vector') is fed into the original DSGC model;</li>
#     <li>The DSGC model process this vector and returns a binary output - the grid stability for that particular set of inputs ('stable' or 'unstable' - a binary classification!);</li>
#     <li>Steps 1 and 2 are executed 'n' times;</li>
#     <li>A large set of vectors and the respective outputs (stability or instability) is created.</li>
# </ol>
# <p>In summary, the original DSGC model was run to generate a set of inputs and outputs that a 'learning machine' can process and make predictions from!</p>
# <p>Per [2], accuracies of "around 80%" have been achieved with the CART-based learning machine.</p>

# %% [markdown]
# ## 2. Objectives of this machine learning exercise

# %% [markdown]
# <p style="text-align: justify">Considering the nature of the problem to be investigated and the dataset properties (as described in Section 3 below), two major objectives are proposed:</p>
# <ol>
#     <li style="text-align: justify">Pursue improvements in predictions with <b>deep learning</b> (Keras' Sequential model);</li>
#     <li style="text-align: justify">Take the opportunity to assess the influence of deep learning architecture (number and size of hidden layers), number of epochs and the relevance of dataset augmentation.</li>
# </ol>

# %% [markdown]
# ## 3. The dataset

# %% [markdown]
# <p style="text-align: justify">The dataset chosen for this machine learning exercise has a synthetic nature and contains results from simulations of grid stability for a reference 4-node star network, as described in 1.2.</p>
# <p style="text-align: justify">The original dataset contains 10,000 observations. As the reference grid is symetric, the dataset can be augmented in 3! (3 factorial) times, or 6 times, representing a permutation of the three consumers occupying three consumer nodes. The augmented version has then <b>60,000 observations</b>. It also contains <b>12 primary predictive features</b> and two dependent variables. </p>
# <p><b>Predictive features</b>:</p>
# <ol>
#     <li>'tau1' to 'tau4': the reaction time of each network participant, a real value within the range 0.5 to 10 ('tau1' corresponds to the supplier node, 'tau2' to 'tau4' to the consumer nodes);</li>
#     <li>'p1' to 'p4': nominal power produced (positive) or consumed (negative) by each network participant, a real value within the range -2.0 to -0.5 for consumers ('p2' to 'p4'). As the total power consumed equals the total power generated, p1 (supplier node) = - (p2 + p3 + p4);</li>
#     <li>'g1' to 'g4': price elasticity coefficient for each network participant, a real value within the range 0.05 to 1.00 ('g1' corresponds to the supplier node, 'g2' to 'g4' to the consumer nodes; 'g' stands for 'gamma');</li>
# </ol>
# <p><b>Dependent variables</b>:</p>
# <ol>
#     <li>'stab': the maximum real part of the characteristic differentia equation root (if positive, the system is linearly unstable; if negative, linearly stable);</li>
#     <li>'stabf': a categorical (binary) label ('stable' or 'unstable').</li>
# </ol>
# <p style="text-align: justify">As there is a direct relationship between 'stab' and 'stabf' ('stabf' = 'stable' if 'stab' <= 0, 'unstable' otherwise), 'stab' will be dropped and 'stabf' will remain as the sole dependent variable.</p>
# <p style="text-align: justify">As the dataset content comes from simulation exercises, there are no missing values. Also, all features are originally numerical, no feature coding is required. Such dataset properties allow for a direct jump to machine modeling without the need of data preprocessing or feature engineering.</p>

# %% [markdown]
# ## 4. Initial setup

# %% [markdown]
# ### 4.1. Importing required libraries

# %% [markdown]
# <p style="text-align: justify">Along with traditional libraries imported for tensor manipulation, mathematical operations and graphics development, three scikit-learn modules (StandardScaler as a scaler, confusion_matrix as the model performance metric of choice and KFold as the cross validation engine) and two Keras deep learning objects (Sequential and Dense) are used in this exercise.</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold

from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from keras.optimizers import SGD
from keras.optimizers import Nadam

from datetime import datetime

# %% [markdown]
# ### 4.2. Customized functions

# %% [markdown]
# <p style="text-align: justify">Functions were developed to assist with graphical analysis of specific dataset elements (features or observations) and mapping correlation. Please refer to the respective docstrings below for details. Note that all function variable names, by coding principle, start with the "f_" string, allowing for containerized processing within the function execution environment, not affecting global variables.</p>

# %%
def assessment(f_data, f_y_feature, f_x_feature, f_index=-1):
    """
    Develops and displays a histogram and a scatter plot for a dependent / independent variable pair from
    a dataframe and, optionally, highlights a specific observation on the plot in a different color (red).
    
    Also optionally, if an independent feature is not informed, the scatterplot is not displayed.
    
    Keyword arguments:
    
    f_data      Tensor containing the dependent / independent variable pair.
                Pandas dataframe
    f_y_feature Dependent variable designation.
                String
    f_x_feature Independent variable designation.
                String
    f_index     If greater or equal to zero, the observation denoted by f_index will be plotted in red.
                Integer
    """
    for f_row in f_data:
        if f_index >= 0:
            f_color = np.where(f_data[f_row].index == f_index,'r','g')
            f_hue = None
        else:
            f_color = 'b'
            f_hue = None
    
    f_fig, f_a = plt.subplots(1, 2, figsize=(16,4))
    
    f_chart1 = sns.distplot(f_data[f_x_feature], ax=f_a[0], kde=False, color='g')
    f_chart1.set_xlabel(f_x_feature,fontsize=10)
    
    if f_index >= 0:
        f_chart2 = plt.scatter(f_data[f_x_feature], f_data[f_y_feature], c=f_color, edgecolors='w')
        f_chart2 = plt.xlabel(f_x_feature, fontsize=10)
        f_chart2 = plt.ylabel(f_y_feature, fontsize=10)
    else:
        f_chart2 = sns.scatterplot(x=f_x_feature, y=f_y_feature, data=f_data, hue=f_hue, legend=False)
        f_chart2.set_xlabel(f_x_feature,fontsize=10)
        f_chart2.set_ylabel(f_y_feature,fontsize=10)

    plt.show()

    
def correlation_map(f_data, f_feature, f_number):
    """
    Develops and displays a heatmap plot referenced to a primary feature of a dataframe, highlighting
    the correlation among the 'n' mostly correlated features of the dataframe.
    
    Keyword arguments:
    
    f_data      Tensor containing all relevant features, including the primary.
                Pandas dataframe
    f_feature   The primary feature.
                String
    f_number    The number of features most correlated to the primary feature.
                Integer
    """
    f_most_correlated = f_data.corr().nlargest(f_number,f_feature)[f_feature].index
    f_correlation = f_data[f_most_correlated].corr()
    
    f_mask = np.zeros_like(f_correlation)
    f_mask[np.triu_indices_from(f_mask)] = True
    with sns.axes_style("white"):
        f_fig, f_ax = plt.subplots(figsize=(20, 10))
        sns.heatmap(f_correlation, mask=f_mask, vmin=-1, vmax=1, square=True,
                    center=0, annot=True, annot_kws={"size": 8}, cmap="PRGn")
    plt.show()

# %% [markdown]
# ### 4.3. Importing required datasets into dataframes

# %% [markdown]
# <p style="text-align: justify">The augmented dataset (60,000 observations) is imported. The dependent variable is map encoded ('stable' replaced with 1, 'unstable' with 0). At last, the 60,000 observations are shuffled.</p>

# %%
sns.set()
start_time = datetime.now()

data = pd.read_csv('../input/smart-grid-stability/smart_grid_stability_augmented.csv')

map1 = {'unstable': 0, 'stable': 1}
data['stabf'] = data['stabf'].replace(map1)

data = data.sample(frac=1)

# %% [markdown]
# ## 5. Exploratory data analysis

# %% [markdown]
# <p style="text-align: justify">A glimpse at the dataset structure confirms observation shuffling and the close relationship between the two original dependent variables 'stab' and 'stabf'.</p>

# %%
data.head()
# Out:
#            tau1      tau2      tau3      tau4        p1        p2        p3  \
# 21095  7.408768  9.408268  3.786504  8.290950  2.718477 -1.047839 -1.145012
# 40940  8.872524  3.740176  9.316562  2.929754  3.665592 -0.898639 -1.047132
# 47732  6.294486  0.614579  2.448256  7.319978  3.907771 -0.750916 -1.983778
# 18183  4.186263  1.792301  3.839522  8.641163  4.288744 -0.676211 -1.722096
# 37155  2.250533  2.914660  5.700492  8.244028  3.215855 -1.006451 -0.717319
#
#              p4        g1        g2        g3        g4      stab  stabf
# 21095 -0.525626  0.851844  0.411093  0.551705  0.771679  0.069179      0
# 40940 -1.719821  0.251020  0.684486  0.523303  0.870646  0.010683      0
# 47732 -1.173077  0.477660  0.894274  0.562188  0.052869 -0.025511      1
# 18183 -1.890437  0.308119  0.277346  0.415176  0.979240  0.018671      0
# 37155 -1.492085  0.058003  0.151129  0.489843  0.758548  0.013472      0

# %% [markdown]
# ### 5.1. Feature assessment

# %% [markdown]
# <p style="text-align: justify">Distribution patterns and the relationship with the 'stab' dependent variable is charted for each of the 12 dataset features.</p>
# <p style="text-align: justify">As this data comes from simulations with predetermined fixed ranges for all features, as described in Section 3, distributions are pretty much uniform across the board, with the exception of 'p1' (absolute sum of 'p2', 'p3' and 'p4'), which follows a normal distribution (as expected) with a very small skew factor of -0.013.</p>

# %%
for column in data.columns:
    assessment(data, 'stab', column, -1)

# %%
data.p1.skew()
# Out:
# -0.012688423269883483

# %% [markdown]
# <p style="text-align: justify">The proportion of observations related to 'unstable' and 'stable' scenarios is mapped.</p>

# %%
print(f'Split of "unstable" (0) and "stable" (1) observations in the original dataset:')
print(data['stabf'].value_counts(normalize=True))
# Out:
# Split of "unstable" (0) and "stable" (1) observations in the original dataset:
# 0    0.638
# 1    0.362
# Name: stabf, dtype: float64

# %% [markdown]
# ### 5.2. Correlation

# %% [markdown]
# <p style="text-align: justify">It is important to verify the correlation between each numerical feature and the dependent variable, as well as correlation among numerical features leading to potential undesired colinearity. The heatmap below provides an overview of correlation between the dependent variable ('stabf') and the 12 numerical features. Note that also the alternative dependent variable ('stab') has been included just to give an idea of how correlated it is with 'stabf'. Such correlation is significant (-0.83), as it should be, which reinforces the decision to drop it, anticipated in Section 3. Also, correlation between 'p1' and its components 'p2', 'p3' and 'p4' is above average, as expected, but not as high o justify any removal. </p>

# %%
correlation_map(data, 'stabf', 14)

# %% [markdown]
# ### 5.3. Segregating train and test sets

# %% [markdown]
# <p style="text-align: justify">As anticipated, the features dataset will contain all 12 original predictive features, while the label dataset will contain only 'stabf' ('stab' is dropped here).</p>
# <p style="text-align: justify">In addition, as the dataset has already been shuffled, the training set will receive the first 54,000 observations, while the testing set will accommodate the last 6,000.</p>
# <p style="text-align: justify">Even considering that the dataset is large enough and well behaved, the percentage of 'stable' and 'unstable' observations is computed for both training and testing sets, just to make sure that the original dataset distribution is maintained after the split - which proved to be the case.</p>
# <p style="text-align: justify">After splitting, Pandas dataframes and series are transformed into Numpy arrays for the remainder of the exercise.</p>

# %%
X = data.iloc[:, :12]
y = data.iloc[:, 13]

X_training = X.iloc[:54000, :]
y_training = y.iloc[:54000]

X_testing = X.iloc[54000:, :]
y_testing = y.iloc[54000:]

ratio_training = y_training.value_counts(normalize=True)
ratio_testing = y_testing.value_counts(normalize=True)
ratio_training, ratio_testing
# Out:
# (0    0.637611
#  1    0.362389
#  Name: stabf, dtype: float64,
#  0    0.6415
#  1    0.3585
#  Name: stabf, dtype: float64)

# %%
X_training = X_training.values
y_training = y_training.values

X_testing = X_testing.values
y_testing = y_testing.values

# %% [markdown]
# ### 5.4. Feature scaling

# %% [markdown]
# <p style="text-align: justify">In preparation for machine learning, scaling is performed based on (fitted to) the training set and applied (with the 'transform' method) to both training and testing sets.</p>

# %%
scaler = StandardScaler()
X_training = scaler.fit_transform(X_training)
X_testing = scaler.transform(X_testing)

# %% [markdown]
# ## 6. Deep Learning

# %% [markdown]
# ### 6.1. Model definition

# %% [markdown]
# <p style="text-align: justify">The artificial neural network (ANN) architecture depicted below is the optimal one evaluated in this study. It reflects an sequential structure with:</p>
# <ul>
#     <li>one input layer (12 input nodes);</li>
#     <li>four hidden layers (288, 288, 24 and 12 nodes, respectively);</li>
#     <li>one single-node output layer.</li>
# </ul>
# <p style="text-align: justify">Alternative architectures were evaluated with variations of the code below. Their performance will be discussed in Section 7.</p>
# <p style="text-align: justify">As features are numerical real numbers within ranges, the choice of 'relu' as the activation function for hidden layers seems straightforward. Similarly, as this is a logistic classification exercise, where the output is binary ('0' for 'unstable', '1' for 'stable', following the map coding used in Section 4.3), the choice of 'sigmoid' as activation for the output layers seems obvious.</p>
# <p style="text-align: justify">Compilation with 'nadam' as optimizer and 'binary_crossentropy' as the loss function follow the same logic. The fitting performance will be assessed using 'accuracy' as the metric of choice.</p>

# %% [markdown]
# <img src="https://i.imgur.com/Uu57iWd.png" width="600" height="600" style="display:none">

# %%
# ANN initialization
classifier = Sequential()

# Input layer and first hidden layer
classifier.add(Dense(units = 288 , kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))

#Second hidden layer
classifier.add(Dense(units = 288, kernel_initializer = 'uniform', activation = 'relu'))

# Third hidden layer
classifier.add(Dense(units = 24, kernel_initializer = 'uniform', activation = 'relu'))

# Fourth hidden layer
classifier.add(Dense(units = 12, kernel_initializer = 'uniform', activation = 'relu'))

# Single-node output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

#Optimzer
#opt = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
#opt=Nadam(learning_rate=0.0005)

# ANN compilation
classifier.compile(optimizer = "nadam", loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#print(X_training.shape)

#classifier = Sequential()
#classifier.add(layers.Conv1D(24, kernel_size=1 , activation='relu', input_shape=(12,1)))
#classifier.add(layers.MaxPooling1D(2))
#classifier.add(layers.Conv1D(48, kernel_size=1, activation='relu'))
#classifier.add(layers.MaxPooling1D(2))
#classifier.add(layers.Conv1D(48, kernel_size=1, activation='relu'))
#classifier.add(layers.MaxPooling1D(3))
#classifier.add(Dense(units = 48, kernel_initializer = 'uniform', activation = 'relu'))
#classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

#classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

#print(classifier.summary())

# %% [markdown]
# ### 6.2. Model fitting

# %% [markdown]
# <p style="text-align: justify">Even considering that data is well behaved and in general uniformly distributed, a cross-validation based fitting is proposed. KFold is the cross-validation engine selected, and 10 different validation sets will be utilized.</p>

# %%
cross_val_round = 1

for train_index, val_index in KFold(10, shuffle=True, random_state=10).split(X_training):
    x_train, x_val = X_training[train_index], X_training[val_index]
    y_train ,y_val = y_training[train_index], y_training[val_index]
    #x_train=x_train.reshape(48600,12,1)
    #x_val=x_val.reshape(5400,12,1)
    classifier.fit(x_train, y_train, epochs=50)
    print(f'\nModel evaluation - Round {cross_val_round}: {classifier.evaluate(x_val, y_val)}\n')
    cross_val_round += 1
# Out:
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.1946 - accuracy: 0.9136
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.1022 - accuracy: 0.9586
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0845 - accuracy: 0.9653
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0767 - accuracy: 0.9692
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0704 - accuracy: 0.9721
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0660 - accuracy: 0.9734
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0622 - accuracy: 0.9747
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0571 - accuracy: 0.9768
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0541 - accuracy: 0.9781
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0502 - accuracy: 0.9795
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0480 - accuracy: 0.9803
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0452 - accuracy: 0.9820
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0430 - accuracy: 0.9830
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0419 - accuracy: 0.9827
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0387 - accuracy: 0.9851
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0378 - accuracy: 0.9848
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0353 - accuracy: 0.9859
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0345 - accuracy: 0.9859
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0326 - accuracy: 0.9866
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0316 - accuracy: 0.9877
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0303 - accuracy: 0.9878
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0282 - accuracy: 0.9888
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0275 - accuracy: 0.9893
# Epoch 24/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.98 - 3s 2ms/step - loss: 0.0275 - accuracy: 0.9896
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0245 - accuracy: 0.9907
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0247 - accuracy: 0.9903
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0231 - accuracy: 0.9915
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0232 - accuracy: 0.9906
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0220 - accuracy: 0.9917
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0217 - accuracy: 0.9919
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0213 - accuracy: 0.9916
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0203 - accuracy: 0.9922
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0197 - accuracy: 0.9929
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0193 - accuracy: 0.9925
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0177 - accuracy: 0.9934
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0177 - accuracy: 0.9934
# Epoch 37/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0179 - accuracy: 0.9938
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0163 - accuracy: 0.9942
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0169 - accuracy: 0.9939
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0160 - accuracy: 0.9940
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0150 - accuracy: 0.9944
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0135 - accuracy: 0.9953
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0150 - accuracy: 0.9943
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0147 - accuracy: 0.9945
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0134 - accuracy: 0.9953
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0138 - accuracy: 0.9948
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0133 - accuracy: 0.9950
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0143 - accuracy: 0.9944
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0130 - accuracy: 0.9953
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0122 - accuracy: 0.9958
# 169/169 [==============================] - 0s 830us/step - loss: 0.0612 - accuracy: 0.9807
#
# Model evaluation - Round 1: [0.061168842017650604, 0.9807407259941101]
#
# Epoch 1/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0170 - accuracy: 0.9940
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0149 - accuracy: 0.9949
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0141 - accuracy: 0.9948
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0130 - accuracy: 0.9952
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0125 - accuracy: 0.9957
# Epoch 6/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0122 - accuracy: 0.9957
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0126 - accuracy: 0.9953
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0126 - accuracy: 0.9953
# Epoch 9/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0111 - accuracy: 0.9957
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0118 - accuracy: 0.9957
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0115 - accuracy: 0.9959
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0105 - accuracy: 0.9961
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0102 - accuracy: 0.9963
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0108 - accuracy: 0.9962
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0100 - accuracy: 0.9964
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9966
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0098 - accuracy: 0.9967
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0096 - accuracy: 0.9966
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9968
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0101 - accuracy: 0.9964
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0096 - accuracy: 0.9966
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9974
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 27/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 28/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0079 - accuracy: 0.9971
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9976
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9976
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0071 - accuracy: 0.9976
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 0.9974
# Epoch 34/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0077 - accuracy: 0.9975
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9977
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0069 - accuracy: 0.9976
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9976
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9974
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0066 - accuracy: 0.9980
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0083 - accuracy: 0.9974
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9978
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0067 - accuracy: 0.9977
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0072 - accuracy: 0.9975
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9981
# Epoch 47/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0066 - accuracy: 0.9977
# Epoch 48/50
# 1519/1519 [==============================] - 6s 4ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 49/50
# 1519/1519 [==============================] - 6s 4ms/step - loss: 0.0062 - accuracy: 0.9977
# Epoch 50/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0062 - accuracy: 0.9979
# 169/169 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9926
#
# Model evaluation - Round 2: [0.020005375146865845, 0.9925925731658936]
#
# Epoch 1/50
# 1519/1519 [==============================] - 6s 4ms/step - loss: 0.0071 - accuracy: 0.9974
# Epoch 2/50
# 1519/1519 [==============================] - 5s 3ms/step - loss: 0.0064 - accuracy: 0.9976
# Epoch 3/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0064 - accuracy: 0.9980
# Epoch 4/50
# 1519/1519 [==============================] - 5s 3ms/step - loss: 0.0064 - accuracy: 0.9977
# Epoch 5/50
# 1519/1519 [==============================] - 5s 3ms/step - loss: 0.0058 - accuracy: 0.9980
# Epoch 6/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9978
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 9/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0065 - accuracy: 0.9980
# Epoch 10/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0064 - accuracy: 0.9978
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9981
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 0.9979
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 15/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9982
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9990
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0054 - accuracy: 0.9983
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9989
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 34/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 38/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 39/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9984
# 169/169 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.9976
#
# Model evaluation - Round 3: [0.007159683853387833, 0.997592568397522]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9981
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 0.9989
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9986
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9989
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9988
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 22/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 27/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9988
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 0.9995
# 169/169 [==============================] - 0s 831us/step - loss: 0.0061 - accuracy: 0.9976
#
# Model evaluation - Round 4: [0.006148884538561106, 0.997592568397522]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 4/50
# 1519/1519 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.99 - 3s 2ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 9/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 0.9989
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0046 - accuracy: 0.9988
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 6.2937e-04 - accuracy: 0.9998
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.4565e-05 - accuracy: 1.0000
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.8942e-06 - accuracy: 1.0000
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2955e-06 - accuracy: 1.0000
# Epoch 21/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 5.8322e-07 - accuracy: 1.0000
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.6094e-07 - accuracy: 1.0000
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1116e-07 - accuracy: 1.0000
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.9436e-08 - accuracy: 1.0000
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.1767e-08 - accuracy: 1.0000
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.8278e-09 - accuracy: 1.0000
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.4857e-09 - accuracy: 1.0000
# Epoch 28/50
# 1519/1519 [==============================] - ETA: 0s - loss: 2.0636e-09 - accuracy: 1.00 - 3s 2ms/step - loss: 2.0563e-09 - accuracy: 1.0000
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.5852e-10 - accuracy: 1.0000
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.6047e-10 - accuracy: 1.0000
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.3202e-10 - accuracy: 1.0000
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2738e-10 - accuracy: 1.0000
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 7.3902e-11 - accuracy: 1.0000
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.6307e-11 - accuracy: 1.0000
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.8012e-11 - accuracy: 1.0000
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.3117e-11 - accuracy: 1.0000
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.1432e-11 - accuracy: 1.0000
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.9379e-11 - accuracy: 1.0000
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.6406e-11 - accuracy: 1.0000
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.7150e-11 - accuracy: 1.0000
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.8364e-11 - accuracy: 1.0000
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.7352e-11 - accuracy: 1.0000: 0s - loss: 2.7551e-11 - accuracy:
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.6646e-11 - accuracy: 1.0000
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.7499e-11 - accuracy: 1.0000
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.5342e-11 - accuracy: 1.0000
# Epoch 46/50
# 1519/1519 [==============================] - ETA: 0s - loss: 2.6247e-11 - accuracy: 1.00 - 3s 2ms/step - loss: 2.5941e-11 - accuracy: 1.0000
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.6196e-11 - accuracy: 1.0000
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.3689e-11 - accuracy: 1.0000
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.4254e-11 - accuracy: 1.0000
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.4724e-11 - accuracy: 1.0000
# 169/169 [==============================] - 0s 871us/step - loss: 9.6443e-06 - accuracy: 1.0000
#
# Model evaluation - Round 5: [9.644300007494166e-06, 1.0]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0115 - accuracy: 0.9977
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.3982e-04 - accuracy: 0.9999
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9989 E
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.0017e-04 - accuracy: 1.0000
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 7.2884e-06 - accuracy: 1.0000:
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9988
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9996
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9988
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 0.9997
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9992: 0s - loss:
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9992
# 169/169 [==============================] - 0s 804us/step - loss: 0.0026 - accuracy: 0.9989
#
# Model evaluation - Round 6: [0.002565048635005951, 0.9988889098167419]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 6.2829e-05 - accuracy: 1.0000
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1587e-05 - accuracy: 1.0000:
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8274e-06 - accuracy: 1.0000
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 7.8068e-07 - accuracy: 1.0000
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.9771e-07 - accuracy: 1.0000
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3463e-07 - accuracy: 1.0000
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.8648e-08 - accuracy: 1.0000
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.5554e-08 - accuracy: 1.0000
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1121e-08 - accuracy: 1.0000
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.7710e-09 - accuracy: 1.0000
# Epoch 15/50
# 1519/1519 [==============================] - ETA: 0s - loss: 2.1293e-09 - accuracy: 1.00 - 3s 2ms/step - loss: 2.1161e-09 - accuracy: 1.0000
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.6530e-10 - accuracy: 1.0000
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.5315e-10 - accuracy: 1.0000
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.2861e-10 - accuracy: 1.0000
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1759e-10 - accuracy: 1.0000
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 6.5674e-11 - accuracy: 1.0000
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.1927e-11 - accuracy: 1.0000
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.1166e-11 - accuracy: 1.0000
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.1807e-11 - accuracy: 1.0000
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8835e-11 - accuracy: 1.0000
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6539e-11 - accuracy: 1.0000
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5915e-11 - accuracy: 1.0000
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6111e-11 - accuracy: 1.0000
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6386e-11 - accuracy: 1.0000
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6620e-11 - accuracy: 1.0000
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6816e-11 - accuracy: 1.0000: 0s -
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.4683e-11 - accuracy: 1.0000: 0s - loss: 1.4314e-11 - ac
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.4822e-11 - accuracy: 1.0000
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.4991e-11 - accuracy: 1.0000
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5101e-11 - accuracy: 1.0000
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5234e-11 - accuracy: 1.0000
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5361e-11 - accuracy: 1.0000
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5465e-11 - accuracy: 1.0000
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5577e-11 - accuracy: 1.0000
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5661e-11 - accuracy: 1.0000
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5756e-11 - accuracy: 1.0000
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5839e-11 - accuracy: 1.0000
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5917e-11 - accuracy: 1.0000
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5989e-11 - accuracy: 1.0000
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6070e-11 - accuracy: 1.0000
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6135e-11 - accuracy: 1.0000
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6197e-11 - accuracy: 1.0000: 0s
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6261e-11 - accuracy: 1.0000
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6313e-11 - accuracy: 1.0000
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6388e-11 - accuracy: 1.0000
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6440e-11 - accuracy: 1.0000
# 169/169 [==============================] - 0s 843us/step - loss: 0.0034 - accuracy: 0.9998
#
# Model evaluation - Round 7: [0.003429819131270051, 0.9998148083686829]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0091 - accuracy: 0.9981
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9991
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9992
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 0.9998
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0061 - accuracy: 0.9991
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 14/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9993
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9995: 0s - loss: 0.0016 - accuracy - ETA: 0s - loss: 0.0017 - accuracy: 0.
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9994
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.7564e-04 - accuracy: 0.9999
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 25/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 26/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 8.1059e-04 - accuracy: 0.9998
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9994
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.2141e-04 - accuracy: 1.0000
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.4169e-06 - accuracy: 1.0000
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.7894e-06 - accuracy: 1.0000
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.6648e-07 - accuracy: 1.0000
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.2603e-07 - accuracy: 1.0000
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.8352e-08 - accuracy: 1.0000
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.1978e-08 - accuracy: 1.0000
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8332e-08 - accuracy: 1.0000
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 8.7365e-09 - accuracy: 1.0000
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.1886e-09 - accuracy: 1.0000
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.0361e-09 - accuracy: 1.0000
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.0023e-09 - accuracy: 1.0000
# Epoch 50/50
# 1519/1519 [==============================] - ETA: 0s - loss: 5.0473e-10 - accuracy: 1.00 - 3s 2ms/step - loss: 5.0180e-10 - accuracy: 1.0000
# 169/169 [==============================] - 0s 862us/step - loss: 0.0035 - accuracy: 0.9998
#
# Model evaluation - Round 8: [0.0034912778064608574, 0.9998148083686829]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0104 - accuracy: 0.9974
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 4/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 14/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 5.7833e-05 - accuracy: 1.0000
# Epoch 15/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 4.0131e-06 - accuracy: 1.0000
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1339e-06 - accuracy: 1.0000
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.0639e-07 - accuracy: 1.0000
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.1194e-07 - accuracy: 1.0000
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 8.7862e-08 - accuracy: 1.0000
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.0975e-08 - accuracy: 1.0000
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.7284e-08 - accuracy: 1.0000
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 7.7732e-09 - accuracy: 1.0000
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.5120e-09 - accuracy: 1.0000
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6094e-09 - accuracy: 1.0000
# Epoch 25/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 7.6434e-10 - accuracy: 1.0000
# Epoch 26/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 3.6099e-10 - accuracy: 1.0000
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8325e-10 - accuracy: 1.0000
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.0135e-10 - accuracy: 1.0000
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.7755e-11 - accuracy: 1.0000
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.6934e-11 - accuracy: 1.0000
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.7467e-11 - accuracy: 1.0000
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.9021e-11 - accuracy: 1.0000
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.5052e-11 - accuracy: 1.0000
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3994e-11 - accuracy: 1.0000
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2232e-11 - accuracy: 1.0000
# Epoch 36/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2426e-11 - accuracy: 1.0000
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2604e-11 - accuracy: 1.0000
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2778e-11 - accuracy: 1.0000
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2954e-11 - accuracy: 1.0000
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3102e-11 - accuracy: 1.0000
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3235e-11 - accuracy: 1.0000
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3394e-11 - accuracy: 1.0000
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3379e-11 - accuracy: 1.0000
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1005e-11 - accuracy: 1.0000
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1099e-11 - accuracy: 1.0000
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1184e-11 - accuracy: 1.0000
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1262e-11 - accuracy: 1.0000
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1347e-11 - accuracy: 1.0000
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1411e-11 - accuracy: 1.0000
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1477e-11 - accuracy: 1.0000
# 169/169 [==============================] - ETA: 0s - loss: 2.2976e-04 - accuracy: 0.99 - 0s 883us/step - loss: 1.5851e-04 - accuracy: 0.9998
#
# Model evaluation - Round 9: [0.00015850865747779608, 0.9998148083686829]
#
# Epoch 1/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 2/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 3/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 4/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 5/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 6/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9994: 0s - loss: 0.0032 - accu
# Epoch 7/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 0.9998
# Epoch 8/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0028 - accuracy: 0.9989
# Epoch 9/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 10/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 11/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 0.9998
# Epoch 12/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0035 - accuracy: 0.9991
# Epoch 13/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 14/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 15/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 16/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 17/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2779e-04 - accuracy: 1.0000
# Epoch 18/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 19/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0032 - accuracy: 0.9994
# Epoch 20/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 21/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 22/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 23/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.1986e-04 - accuracy: 0.9999
# Epoch 24/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 25/50
# 1519/1519 [==============================] - 4s 3ms/step - loss: 6.7469e-05 - accuracy: 1.0000
# Epoch 26/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 9.0478e-06 - accuracy: 1.0000
# Epoch 27/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.0139e-06 - accuracy: 1.0000
# Epoch 28/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.3715e-06 - accuracy: 1.0000
# Epoch 29/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.6229e-06 - accuracy: 1.0000
# Epoch 30/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.3003e-06 - accuracy: 1.0000
# Epoch 31/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.1706e-06 - accuracy: 1.0000
# Epoch 32/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 33/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 34/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 35/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.5493e-04 - accuracy: 0.9998
# Epoch 36/50
# 1519/1519 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 37/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 38/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 39/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 40/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.0901e-04 - accuracy: 1.0000
# Epoch 41/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.2417e-06 - accuracy: 1.0000
# Epoch 42/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.2196e-06 - accuracy: 1.0000
# Epoch 43/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 5.0936e-07 - accuracy: 1.0000
# Epoch 44/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 2.2229e-07 - accuracy: 1.0000
# Epoch 45/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 9.9449e-08 - accuracy: 1.0000
# Epoch 46/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 4.2843e-08 - accuracy: 1.0000
# Epoch 47/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8692e-08 - accuracy: 1.0000
# Epoch 48/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 8.3448e-09 - accuracy: 1.0000
# Epoch 49/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 3.9108e-09 - accuracy: 1.0000
# Epoch 50/50
# 1519/1519 [==============================] - 3s 2ms/step - loss: 1.8254e-09 - accuracy: 1.0000
# 169/169 [==============================] - 0s 834us/step - loss: 3.7396e-04 - accuracy: 0.9998
#
# Model evaluation - Round 10: [0.00037395840627141297, 0.9998148083686829]

# %% [markdown]
# ### 6.3. Predicting smart grid stability

# %% [markdown]
# <p style="text-align: justify">After fitting the model to the training set, it is time to extract predictions for the testing set and segregate those above the 'threshold' of 0.5 ('unstable' cases below the threshold, 'stable' cases above it).</p>

# %%
print(X_testing.shape)
#X_testing=X_testing.reshape(6000,12,1)
y_pred = classifier.predict(X_testing)
#y_pred = y_pred.reshape(6000,1)
y_pred[y_pred <= 0.5] = 0
y_pred[y_pred > 0.5] = 1
# Out:
# (6000, 12)

# %% [markdown]
# ## 7. Results

# %% [markdown]
# ### 7.1. Classification performance - Confusion matrix

# %% [markdown]
# <p style="text-align: justify">The segregation described in Section 6.3 allows for the construction of a confusion matrix.</p>

# %%
#print(y_pred)
cm = confusion_matrix(y_testing, y_pred)
print(cm)
# Out:
# [[3827   22]
#  [  13 2138]]

# %%
print(f'Accuracy per the confusion matrix: {(cm[0][0]+cm[1][1])/cm.sum()*100:.2f}%')
# Out:
# Accuracy per the confusion matrix: 99.42%

# %% [markdown]
# ### 7.2. Alternative configurations

# %% [markdown]
# <p style="text-align: justify">The architecture and the hyperparameters selected above led to the best prediction performance on the test set.</p>
# <p style="text-align: justify">In addition, several other combinations were evaluated for both the original dataset with 1,000 observations and the augmented dataset with 6,000 observations. It is important to emphasize that in this comparative assessment <b>no shuffling</b> of any type, at any part of the exercise, was performed, so that the very same testing set was exposed to model after fitting for performance assessment.</p>
# <p style="text-align: justify">The table below summarizes obtained results:</p>

# %% [markdown]
# <img src="https://i.imgur.com/knrs5b6.png?1">
# <img src="https://i.imgur.com/QhCvjB8.png?1">

# %% [markdown]
# ## 8. Discussion and Final Remarks

# %% [markdown]
# <p style="text-align: justify">Specific aspects of this deep learning exercise demand special attention:</p>
# <ol>
#     <li style="text-align: justify">Deep learning proved to be an outstanding prediction tool for this particular application. Even considering that the dataset is well behaved and needed no significant preprocessing, the <b>high accuracies</b> obtained on the testing set confirm that a deep learning model may be safely considered. It would though be up to a smart grid operator to confirm if the accuracy level obtained with deep learning would suffice in practical terms (live network);</li>
#     <li style="text-align: justify">As expected, more complex ANN architectures <b>performed better</b> than simpler ones;</li>
#     <li style="text-align: justify">An <b>increased number of epochs</b> considered during fitting also plays a major role. It is evident that the more the model is exposed to the training set, the better the prediction accuracy;</li>
#     <li style="text-align: justify">From a machine learning exercise perspective, the use of an <b>augmented dataset</b> with 6,000 observations contributed significantly to better results;</li>
#     <li style="text-align: justify">It must be noted that input parameters utilized in the original DSGC simulations fall within predetermined ranges. As a follow-up step in the validation of this learning machine, it would be interesting to assess its performance using a new test set with observations obtained from simulations with input parameter values residing in other alternative ranges.
# </ol>

# %%
end_time = datetime.now()

print('\nStart time', start_time)
print('End time', end_time)
print('Time elapsed', end_time - start_time)
# Out:
# Start time 2020-07-19 22:03:49.980486
# End time 2020-07-19 22:30:15.745305
# Time elapsed 0:26:25.764819
